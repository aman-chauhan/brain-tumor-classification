# %% [markdown]
# # Visualizing Results from Classifier Training

# %% [markdown]
# ## Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import os
import gc

# %matplotlib inline

# %% [markdown]
# ## Create Directory if not exists

# %%
base_path = os.path.join('docs', 'classifier')
if not os.path.exists(base_path):
    os.mkdir(base_path)

# %% [markdown]
# ## Fetch the best hyperparameter configurations

# %%
config = json.load(open(os.path.join('logs', 'clf_config.json'), 'r'))

# %% [markdown]
# ## Results from Tuning DenseNet 121 based Models

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Comparitive Performance of DenseNet Models on various Dropouts', fontsize=24)
fig.set_figwidth(24)
fig.set_figheight(18)

ax[0, 1].set_title('Validation Loss/Epoch', fontsize=15)
ax[0, 0].set_title('Training Loss/Epoch', fontsize=15)
ax[1, 1].set_title('Validation Accuracy/Epoch', fontsize=15)
ax[1, 0].set_title('Training Accuracy/Epoch', fontsize=15)

for i in range(1,6):
    df = pd.read_csv(os.path.join('logs', 'clf_densenet_{}.csv'.format(i / 10)))
    ax[0, 1].plot(df['val_loss'], label='Dropout - {}'.format(i / 10))
    ax[0, 0].plot(df['loss'], label='Dropout - {}'.format(i / 10))
    ax[1, 1].plot(df['val_categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    ax[1, 0].plot(df['categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    del df

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

gc.collect()
plt.savefig(os.path.join(base_path, 'densenet.png'), bbox_inches='tight')

# %% [markdown]
# ## Results from Tuning Inception V3 based Models

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Comparitive Performance of Inception Models on various Dropouts', fontsize=24)
fig.set_figwidth(24)
fig.set_figheight(18)

ax[0, 1].set_title('Validation Loss/Epoch', fontsize=15)
ax[0, 0].set_title('Training Loss/Epoch', fontsize=15)
ax[1, 1].set_title('Validation Accuracy/Epoch', fontsize=15)
ax[1, 0].set_title('Training Accuracy/Epoch', fontsize=15)

for i in range(1,6):
    df = pd.read_csv(os.path.join('logs', 'clf_inception_{}.csv'.format(i / 10)))
    ax[0, 1].plot(df['val_loss'], label='Dropout - {}'.format(i / 10))
    ax[0, 0].plot(df['loss'], label='Dropout - {}'.format(i / 10))
    ax[1, 1].plot(df['val_categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    ax[1, 0].plot(df['categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    del df

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

gc.collect()
plt.savefig(os.path.join(base_path, 'inception.png'), bbox_inches='tight')

# %% [markdown]
# ## Results from Tuning InceptionResNet V2 based Models

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Comparitive Performance of InceptionResNet Models on various Dropouts', fontsize=24)
fig.set_figwidth(24)
fig.set_figheight(18)

ax[0, 1].set_title('Validation Loss/Epoch', fontsize=15)
ax[0, 0].set_title('Training Loss/Epoch', fontsize=15)
ax[1, 1].set_title('Validation Accuracy/Epoch', fontsize=15)
ax[1, 0].set_title('Training Accuracy/Epoch', fontsize=15)

for i in range(1,6):
    df = pd.read_csv(os.path.join('logs', 'clf_inceptionresnet_{}.csv'.format(i / 10)))
    ax[0, 1].plot(df['val_loss'], label='Dropout - {}'.format(i / 10))
    ax[0, 0].plot(df['loss'], label='Dropout - {}'.format(i / 10))
    ax[1, 1].plot(df['val_categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    ax[1, 0].plot(df['categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    del df

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

gc.collect()
plt.savefig(os.path.join(base_path, 'inceptionresnet.png'), bbox_inches='tight')

# %% [markdown]
# ## Results from Tuning ResNet 50 based Models

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Comparitive Performance of ResNet Models on various Dropouts', fontsize=24)
fig.set_figwidth(24)
fig.set_figheight(18)

ax[0, 1].set_title('Validation Loss/Epoch', fontsize=15)
ax[0, 0].set_title('Training Loss/Epoch', fontsize=15)
ax[1, 1].set_title('Validation Accuracy/Epoch', fontsize=15)
ax[1, 0].set_title('Training Accuracy/Epoch', fontsize=15)

for i in range(1,6):
    df = pd.read_csv(os.path.join('logs', 'clf_resnet_{}.csv'.format(i / 10)))
    ax[0, 1].plot(df['val_loss'], label='Dropout - {}'.format(i / 10))
    ax[0, 0].plot(df['loss'], label='Dropout - {}'.format(i / 10))
    ax[1, 1].plot(df['val_categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    ax[1, 0].plot(df['categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    del df

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

gc.collect()
plt.savefig(os.path.join(base_path, 'resnet.png'), bbox_inches='tight')

# %% [markdown]
# ## Results from Tuning VGG 19 based Models

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Comparitive Performance of VGG Models on various Dropouts', fontsize=24)
fig.set_figwidth(24)
fig.set_figheight(18)

ax[0, 1].set_title('Validation Loss/Epoch', fontsize=15)
ax[0, 0].set_title('Training Loss/Epoch', fontsize=15)
ax[1, 1].set_title('Validation Accuracy/Epoch', fontsize=15)
ax[1, 0].set_title('Training Accuracy/Epoch', fontsize=15)

for i in range(1,6):
    df = pd.read_csv(os.path.join('logs', 'clf_vgg_{}.csv'.format(i / 10)))
    ax[0, 1].plot(df['val_loss'], label='Dropout - {}'.format(i / 10))
    ax[0, 0].plot(df['loss'], label='Dropout - {}'.format(i / 10))
    ax[1, 1].plot(df['val_categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    ax[1, 0].plot(df['categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    del df

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

gc.collect()
plt.savefig(os.path.join(base_path, 'vgg.png'), bbox_inches='tight')

# %% [markdown]
# ## Results from Tuning Xception based Models

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
fig.suptitle('Comparitive Performance of Xception Models on various Dropouts', fontsize=24)
fig.set_figwidth(24)
fig.set_figheight(18)

ax[0, 1].set_title('Validation Loss/Epoch', fontsize=15)
ax[0, 0].set_title('Training Loss/Epoch', fontsize=15)
ax[1, 1].set_title('Validation Accuracy/Epoch', fontsize=15)
ax[1, 0].set_title('Training Accuracy/Epoch', fontsize=15)

for i in range(1,6):
    df = pd.read_csv(os.path.join('logs', 'clf_xception_{}.csv'.format(i / 10)))
    ax[0, 1].plot(df['val_loss'], label='Dropout - {}'.format(i / 10))
    ax[0, 0].plot(df['loss'], label='Dropout - {}'.format(i / 10))
    ax[1, 1].plot(df['val_categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    ax[1, 0].plot(df['categorical_accuracy'], label='Dropout - {}'.format(i / 10))
    del df

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

gc.collect()
plt.savefig(os.path.join(base_path, 'xception.png'), bbox_inches='tight')

# %% [markdown]
# ## Best Tuned Hyperparameter for Each Type of Model

# %%
for key in sorted(config.keys()):
    print('{:15} - {}'.format(key, config[key]))
# Out:
# densenet        - 0.5
# inception       - 0.2
# inceptionresnet - 0.4
# resnet          - 0.1
# vgg             - 0.4
# xception        - 0.5

# %% [markdown]
# ## Tabulated Results for different Classifiers

# %%
df = pd.read_csv(os.path.join('logs', 'clf_results.csv'),
                 usecols=['Name', 'Training Accuracy', 'Validation Accuracy', 'Test Accuracy'],
                 index_col='Name')
print(df.sort_values(by='Test Accuracy', ascending=False))
# Out:
#                  Training Accuracy  Validation Accuracy  Test Accuracy
# Name
# vgg                       0.819226             0.737963       0.734496
# densenet                  0.657738             0.668056       0.671027
# inceptionresnet           0.577679             0.614352       0.604167
# inception                 0.739048             0.595833       0.599806
# resnet                    0.609286             0.469907       0.500000
# xception                  0.641369             0.127315       0.119186
